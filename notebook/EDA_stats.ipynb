# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv(r'C:\Users\rashid\Desktop\analysis_project\notebook\data\raw\all_player_stats.csv')
df.copy()
df.head()
# Out:
#    player_id          league  appearances  matches_started  minutes_played  \
# 0     804508  Premier League           29               23            1907
# 1     934235  Premier League           27               22            2001
# 2     794839  Premier League           11                2             306
# 3     922573  Premier League           25                9             852
# 4     836705  Premier League            6                3             264
#
#    goals  assists  expected_goals  expected_assists  rating  total_shots  \
# 0     11        0            9.35              1.77    6.57           43
# 1      6        3            6.99              5.76    7.21           63
# 2      2        0            1.76              0.20    6.53           14
# 3      1        3            3.38              0.99    6.62           25
# 4      0        1            0.31              0.10    6.65            5
#
#    shots_on_target  yellow_cards  red_cards  tackles  interceptions  saves
# ...

# %%
df.shape
# Out:
# (3651, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3651 entries, 0 to 3650
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   player_id         3651 non-null   int64
#  1   league            3651 non-null   object
#  2   appearances       3651 non-null   int64
#  3   matches_started   3651 non-null   int64
#  4   minutes_played    3651 non-null   int64
#  5   goals             3651 non-null   int64
#  6   assists           3651 non-null   int64
#  7   expected_goals    3134 non-null   float64
#  8   expected_assists  3637 non-null   float64
#  9   rating            3651 non-null   float64
#  10  total_shots       3651 non-null   int64
#  11  shots_on_target   3651 non-null   int64
#  12  yellow_cards      3651 non-null   int64
#  13  red_cards         3651 non-null   int64
#  14  tackles           3651 non-null   int64
#  15  interceptions     3651 non-null   int64
# ...

# %%
df.describe()
# Out:
#        player_id  appearances  matches_started  minutes_played   goals  \
# count    3651.00      3651.00          3651.00         3651.00 3651.00
# mean   913540.31        17.03            12.32         1107.33    1.50
# std    453257.69         8.32             8.80          745.16    2.57
# min       791.00         1.00             0.00            1.00    0.00
# 25%    798880.50        10.00             4.00          455.50    0.00
# 50%    945062.00        19.00            11.00         1037.00    1.00
# 75%   1122606.50        24.00            20.00         1728.50    2.00
# max   2492573.00        31.00            31.00         2790.00   31.00
#
#        assists  expected_goals  expected_assists  rating  total_shots  \
# count  3651.00         3134.00           3637.00 3651.00      3651.00
# mean      1.05            1.81              1.09    6.73        14.04
# std       1.62            2.39              1.33    0.57        15.82
# ...

# %%
df.isna().sum()
# Out:
# player_id             0
# league                0
# appearances           0
# matches_started       0
# minutes_played        0
# goals                 0
# assists               0
# expected_goals      517
# expected_assists     14
# rating                0
# total_shots           0
# shots_on_target       0
# yellow_cards          0
# red_cards             0
# tackles               0
# interceptions         0
# saves                 0
# dtype: int64

# %%
df[df['expected_goals'].isnull()]
# Out:
#       player_id          league  appearances  matches_started  minutes_played  \
# 20      1144630  Premier League           14                6             678
# 22       581310  Premier League           31               31            2790
# 34       136710  Premier League            1                0              12
# 40       152077  Premier League            7                4             363
# 46       824509  Premier League           27               27            2430
# ...         ...             ...          ...              ...             ...
# 3625    1210422       Super Lig            9                9             810
# 3640    1082393       Super Lig            1                0               8
# 3647    1640309       Super Lig            1                0               8
# 3649     807093       Super Lig            4                2             227
# 3650     283847       Super Lig           27               27            2430
#
# ...

# %%
df[df['expected_assists'].isnull()]
# Out:
#       player_id          league  appearances  matches_started  minutes_played  \
# 69      1142182  Premier League            1                0              10
# 223      301288  Premier League            1                0              11
# 401     1403130  Premier League            1                0               1
# 829      999178          LaLiga            2                0              11
# 1264    1435226         Serie A            1                0               1
# 1554    1440627      Bundesliga            1                0               1
# 1668    1996846      Bundesliga            2                0              20
# 1927     174975         Ligue 1            1                0               1
# 2518    1801303      Eredivisie            2                0              10
# 2617    1638397      Eredivisie            1                0              11
# 2691    1922946      Eredivisie            1                0               1
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df['expected_goals'].isnull()]['league'].value_counts()
# Out:
# league
# Super Lig         77
# Liga Portugal     70
# Ligue 1           69
# Premier League    65
# Serie A           65
# Eredivisie        65
# LaLiga            57
# Bundesliga        49
# Name: count, dtype: int64

# %%
df['player_id'].nunique()
# Out:
# 3651 3651

# %%
df.value_counts('league')
# Out:
# league
# LaLiga            493
# Serie A           492
# Premier League    468
# Ligue 1           442
# Liga Portugal     441
# Eredivisie        439
# Super Lig         439
# Bundesliga        437
# Name: count, dtype: int64

# %%
df.groupby('league')['goals'].mean().sort_values(ascending=False)
# Out:
# league
# Eredivisie       1.72
# Bundesliga       1.71
# Premier League   1.70
# LaLiga           1.53
# Serie A          1.42
# Ligue 1          1.39
# Liga Portugal    1.28
# Super Lig        1.24
# Name: goals, dtype: float64

# %%
df.groupby('league')['rating'].mean().sort_values(ascending=False)
# Out:
# league
# Eredivisie       6.77
# LaLiga           6.77
# Ligue 1          6.75
# Serie A          6.73
# Liga Portugal    6.73
# Premier League   6.73
# Bundesliga       6.70
# Super Lig        6.68
# Name: rating, dtype: float64

# %%
df.loc[df['goals'].idxmax()]
# Out:
# player_id               108579
# league              Bundesliga
# appearances                 26
# matches_started             23
# minutes_played            2067
# goals                       31
# assists                      5
# expected_goals           24.38
# expected_assists          3.65
# rating                    7.92
# total_shots                108
# shots_on_target             61
# yellow_cards                 1
# red_cards                    0
# tackles                     17
# interceptions                7
# saves                        0
# Name: 1453, dtype: object

# %%
df.loc[df['rating'].idxmax()]
# Out:
# player_id               842718
# league              Bundesliga
# appearances                  1
# matches_started              1
# minutes_played              90
# goals                        0
# assists                      0
# expected_goals             NaN
# expected_assists          0.00
# rating                    9.70
# total_shots                  0
# shots_on_target              0
# yellow_cards                 0
# red_cards                    0
# tackles                      0
# interceptions                0
# saves                        6
# Name: 1664, dtype: object

# %%
df.loc[df['saves'].idxmax()]
# Out:
# player_id              1393970
# league              Eredivisie
# appearances                 28
# matches_started             28
# minutes_played            2520
# goals                        0
# assists                      0
# expected_goals            0.02
# expected_assists          0.22
# rating                    7.14
# total_shots                  1
# shots_on_target              0
# yellow_cards                 1
# red_cards                    0
# tackles                      0
# interceptions                0
# saves                      134
# Name: 2694, dtype: object

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['goals'], bins=30)
plt.title('Goals Distribution')
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.boxplot(x='league', y='rating', data=df, showfliers=False)
plt.xticks(rotation=45)
plt.title('Rating by League')
plt.show()

# %%
df['expected_goals'] = df['expected_goals'].fillna(df['expected_goals'].median())
df['expected_assists'] = df['expected_assists'].fillna(df['expected_assists'].median())
df[df['expected_goals'].isnull()]
# Out:
# Empty DataFrame
# Columns: [player_id, league, appearances, matches_started, minutes_played, goals, assists, expected_goals, expected_assists, rating, total_shots, shots_on_target, yellow_cards, red_cards, tackles, interceptions, saves]
# Index: []

# %%
df.to_csv(r'C:\Users\rashid\Desktop\analysis_project\notebook\data\processed\cleaned_stats.csv', index=False)
