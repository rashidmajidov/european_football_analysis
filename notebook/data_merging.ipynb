# %%
import pandas as pd

# %%
df_stats = pd.read_csv(r'C:\Users\rashid\Desktop\analysis_project\notebook\data\processed\cleaned_stats.csv')
df_profiles = pd.read_csv(r'C:\Users\rashid\Desktop\analysis_project\notebook\data\processed\cleaned_profiles.csv')

# %%
df_merged = pd.merge(df_stats, df_profiles, on='player_id', how='inner')

print(df_merged.shape)
df_merged.head()
# Out:
# (3651, 21)
#    player_id        league_x  appearances  matches_started  minutes_played  \
# 0     804508  Premier League           29               23            1907
# 1     934235  Premier League           27               22            2001
# 2     794839  Premier League           11                2             306
# 3     922573  Premier League           25                9             852
# 4     836705  Premier League            6                3             264
#
#    goals  assists  expected_goals  expected_assists    rating  ...  \
# 0     11        0          9.3498          1.767505  6.572414  ...
# 1      6        3          6.9941          5.761951  7.214815  ...
# 2      2        0          1.7605          0.203329  6.527273  ...
# 3      1        3          3.3793          0.991020  6.616000  ...
# 4      0        1          0.3077          0.097873  6.650000  ...
#
#    shots_on_target  yellow_cards  red_cards  tackles  interceptions  saves  \
# ...

# %%
df_merged.to_csv(r'C:\Users\rashid\Desktop\analysis_project\notebook\data\processed\cleaned_data.csv', index=False)
